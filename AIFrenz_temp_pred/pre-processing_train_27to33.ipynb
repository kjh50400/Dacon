# %%
import pandas as pd
from IPython.display import display
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
from matplotlib import gridspec
# %matplotlib inline

from matplotlib import font_manager, rc
font_path='c:/Windows/Fonts/malgun.ttf'
font_name= font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
DIR_DATA = './AIFrenz_Season1_dataset/'
DIR_TRAIN = DIR_DATA + 'train.csv'
DIR_TEST = DIR_DATA + 'test.csv'

# %%
train = pd.read_csv(DIR_TRAIN)

print(train.shape)
display(train.head())
# Out:
# (4752, 60)
#    id  X00    X01  X02  X03  X04     X05    X06   X07     X08  ...  Y09  Y10  \
# 0   0  9.7  988.8  1.2  0.6  0.0  1009.3  989.6  12.2  1009.9  ...  7.0  7.5
# 1   1  9.3  988.9  1.7  1.9  0.0  1009.3  989.6  12.1  1010.0  ...  6.5  7.5
# 2   2  9.4  989.0  1.1  2.3  0.0  1009.2  989.7  12.1  1010.1  ...  6.5  7.5
# 3   3  9.4  988.9  1.5  0.7  0.0  1009.2  989.6  12.0  1010.0  ...  6.0  7.0
# 4   4  9.2  988.9  0.8  1.7  0.0  1009.2  989.7  12.0  1010.1  ...  6.0  7.0
#
#    Y11  Y12   Y13  Y14  Y15  Y16  Y17  Y18
# 0  7.0  9.0  10.0  9.5  9.0  8.0  9.0  NaN
# 1  7.0  8.5  10.0  9.5  9.0  7.5  9.0  NaN
# 2  6.5  8.0   9.5  9.5  8.5  7.5  8.5  NaN
# 3  6.0  8.0   9.5  9.0  8.5  7.5  8.5  NaN
# 4  6.0  7.5   9.5  9.0  8.5  7.5  8.5  NaN
#
# [5 rows x 60 columns]

# %%
Temperature = ['X00', 'X07', 'X28', 'X31', 'X32']
localP = ['X01', 'X06', 'X22', 'X27', 'X29']
windV = ['X02', 'X03', 'X18', 'X24', 'X26']
rain = ['X04', 'X10', 'X21', 'X36', 'X39']
seaP = ['X05', 'X08', 'X09', 'X23', 'X33']
solar = ['X11', 'X14', 'X16', 'X19', 'X34']
humi = ['X12', 'X20', 'X30', 'X37', 'X38']
windD = ['X13', 'X15', 'X17', 'X25', 'X35']
sensor = ['Y00', 'Y01', 'Y02', 'Y03', 'Y04',
          'Y05', 'Y06', 'Y07', 'Y08', 'Y09', 
          'Y10', 'Y11', 'Y12', 'Y13', 'Y14', 
          'Y15', 'Y16', 'Y17']

# %%
X_train = train.loc[:, 'X00':'X39']

print(X_train.shape)
display(X_train.head())
# Out:
# (4752, 40)
#    X00    X01  X02  X03  X04     X05    X06   X07     X08     X09  ...   X30  \
# 0  9.7  988.8  1.2  0.6  0.0  1009.3  989.6  12.2  1009.9  1009.8  ...  69.1
# 1  9.3  988.9  1.7  1.9  0.0  1009.3  989.6  12.1  1010.0  1009.9  ...  70.3
# 2  9.4  989.0  1.1  2.3  0.0  1009.2  989.7  12.1  1010.1  1010.1  ...  71.5
# 3  9.4  988.9  1.5  0.7  0.0  1009.2  989.6  12.0  1010.0  1010.0  ...  73.2
# 4  9.2  988.9  0.8  1.7  0.0  1009.2  989.7  12.0  1010.1  1010.0  ...  74.3
#
#    X31   X32     X33  X34    X35  X36   X37   X38  X39
# 0  8.2  10.7  1010.1  0.0  256.4  0.0  77.2  62.6  0.0
# 1  8.3  10.3  1010.1  0.0  215.4  0.0  77.3  63.5  0.0
# 2  8.0   9.7  1010.0  0.0  235.2  0.0  77.3  63.9  0.0
# 3  7.7   9.4  1010.1  0.0  214.0  0.0  77.5  64.5  0.0
# 4  7.4   9.4  1010.1  0.0  174.9  0.0  78.0  65.0  0.0
#
# [5 rows x 40 columns]

# %%
fig = plt.figure(figsize=(30,10))
spec = gridspec.GridSpec(ncols=3, nrows=1, width_ratios=[1,1,1])
ax1 = fig.add_subplot(spec[0])
ax2 = fig.add_subplot(spec[1])
ax3 = fig.add_subplot(spec[2])

ax1.plot(X_train[Temperature].iloc[-144*9:-144*6])
ax1.set_ylim(14, 32)
# ax1.set_xlim(0, 144*33)
ax1.grid(which='both', axis='both')

ax2.plot(X_train[Temperature].iloc[-144*6:-144*3])
ax2.set_ylim(14, 32)
# ax2.set_xlim(0, 144*80)
ax2.grid(which='both', axis='both')

ax3.plot(X_train[Temperature].iloc[-144*3:-1])
ax3.set_ylim(14, 32)
# ax2.set_xlim(0, 144*80)
ax3.grid(which='both', axis='both')

plt.show()

# %%
fig = plt.figure(figsize=(30,10))
spec = gridspec.GridSpec(ncols=2, nrows=1, width_ratios=[1,1])
ax1 = fig.add_subplot(spec[0])
ax2 = fig.add_subplot(spec[1])

ax1.plot(X_train[localP].iloc[-144*6:-144*3])
ax1.set_ylim(980, 1015)
# ax1.set_xlim(0, 144*33)
ax1.grid(which='both', axis='both')

ax2.plot(X_train[localP].iloc[-144*3:-1])
ax2.set_ylim(980, 1015)
# ax2.set_xlim(0, 144*80)
ax2.grid(which='both', axis='both')

plt.show()

# %%
fig = plt.figure(figsize=(30,10))
spec = gridspec.GridSpec(ncols=2, nrows=1, width_ratios=[1,1])
ax1 = fig.add_subplot(spec[0])
ax2 = fig.add_subplot(spec[1])

ax1.plot(X_train[windV].iloc[-144*6:-144*3])
ax1.set_ylim(0, 7)
# ax1.set_xlim(0, 144*33)
ax1.grid(which='both', axis='both')

ax2.plot(X_train[windV].iloc[-144*3:-1])
ax2.set_ylim(0, 7)
# ax2.set_xlim(0, 144*80)
ax2.grid(which='both', axis='both')

plt.show()

# %%
fig = plt.figure(figsize=(30,10))
spec = gridspec.GridSpec(ncols=2, nrows=1, width_ratios=[1,1])
ax1 = fig.add_subplot(spec[0])
ax2 = fig.add_subplot(spec[1])

ax1.plot(X_train[rain].iloc[-144*6:-144*3])
ax1.set_ylim(0, 12)
# ax1.set_xlim(0, 144*33)
ax1.grid(which='both', axis='both')

ax2.plot(X_train[rain].iloc[-144*3:-1])
ax2.set_ylim(0, 12)
# ax2.set_xlim(0, 144*80)
ax2.grid(which='both', axis='both')

plt.show()

# %%
fig = plt.figure(figsize=(30,10))
spec = gridspec.GridSpec(ncols=2, nrows=1, width_ratios=[1,1])
ax1 = fig.add_subplot(spec[0])
ax2 = fig.add_subplot(spec[1])

ax1.plot(X_train[seaP].iloc[-144*6:-144*3])
ax1.set_ylim(1000, 1015)
# ax1.set_xlim(0, 144*33)
ax1.grid(which='both', axis='both')

ax2.plot(X_train[seaP].iloc[-144*3:-1])
ax2.set_ylim(1000, 1015)
# ax2.set_xlim(0, 144*80)
ax2.grid(which='both', axis='both')

plt.show()

# %%
fig = plt.figure(figsize=(30,10))
spec = gridspec.GridSpec(ncols=2, nrows=1, width_ratios=[1,1])
ax1 = fig.add_subplot(spec[0])
ax2 = fig.add_subplot(spec[1])

ax1.plot(X_train[solar].iloc[-144*6:-144*3])
ax1.set_ylim(0, 35)
# ax1.set_xlim(0, 144*33)
ax1.grid(which='both', axis='both')

ax2.plot(X_train[solar].iloc[-144*3:-1])
ax2.set_ylim(0, 35)
# ax2.set_xlim(0, 144*80)
ax2.grid(which='both', axis='both')

plt.show()

# %%
fig = plt.figure(figsize=(30,10))
spec = gridspec.GridSpec(ncols=2, nrows=1, width_ratios=[1,1])
ax1 = fig.add_subplot(spec[0])
ax2 = fig.add_subplot(spec[1])

ax1.plot(X_train[humi].iloc[-144*6:-144*3])
ax1.set_ylim(30, 100)
# ax1.set_xlim(0, 144*33)
ax1.grid(which='both', axis='both')

ax2.plot(X_train[humi].iloc[-144*3:-1])
ax2.set_ylim(30, 100)
# ax2.set_xlim(0, 144*80)
ax2.grid(which='both', axis='both')

plt.show()

# %%
fig = plt.figure(figsize=(30,10))
spec = gridspec.GridSpec(ncols=2, nrows=1, width_ratios=[1,1])
ax1 = fig.add_subplot(spec[0])
ax2 = fig.add_subplot(spec[1])

ax1.plot(X_train[windD].iloc[-144*6:-144*3])
ax1.set_ylim(0, 365)
# ax1.set_xlim(0, 144*33)
ax1.grid(which='both', axis='both')

ax2.plot(X_train[windD].iloc[-144*3:-1])
ax2.set_ylim(0, 365)
# ax2.set_xlim(0, 144*80)
ax2.grid(which='both', axis='both')

plt.show()

# %%
fig = plt.figure(figsize=(30,10))
spec = gridspec.GridSpec(ncols=2, nrows=1, width_ratios=[1,1])
ax1 = fig.add_subplot(spec[0])
ax2 = fig.add_subplot(spec[1])

ax1.plot(train[['Y01','Y02']].iloc[-144*6:-144*3])
ax1.set_ylim(15, 45)
# ax1.set_xlim(0, 144*33)
ax1.grid(which='both', axis='both')

ax2.plot(train['Y18'].iloc[-144*3:-1])
ax2.set_ylim(15, 45)
# ax2.set_xlim(0, 144*80)
ax2.grid(which='both', axis='both')

plt.show()

# %%
fig = plt.figure(figsize=(30,10))
spec = gridspec.GridSpec(ncols=2, nrows=1, width_ratios=[1,1])
ax1 = fig.add_subplot(spec[0])
ax2 = fig.add_subplot(spec[1])

ax1.plot(train[sensor[5:10]].iloc[-144*6:-144*3])
ax1.set_ylim(10, 50)
# ax1.set_xlim(0, 144*33)
ax1.grid(which='both', axis='both')

ax2.plot(train['Y18'].iloc[-144*3:-1])
ax2.set_ylim(10, 50)
# ax2.set_xlim(0, 144*80)
ax2.grid(which='both', axis='both')

plt.show()

# %%
train_T_sensor_corr = train[Temperature+sensor].corr()

plt.figure(figsize=(20,10))

ax = sns.heatmap(train_T_sensor_corr, cmap='RdBu', annot=True, vmin=0, vmax=1)

plt.show()

# %%
train_T_sensor_corr[Temperature].loc['Y00':]
# Out:
#           X00       X07       X28       X31       X32
# Y00  0.912809  0.979172  0.974490  0.918779  0.921823
# Y01  0.951641  0.970238  0.953917  0.956140  0.956146
# Y02  0.954500  0.973252  0.958521  0.957152  0.960426
# Y03  0.729502  0.841002  0.857562  0.758773  0.747431
# Y04  0.728564  0.840372  0.856534  0.758412  0.746524
# Y05  0.906096  0.892414  0.864041  0.899776  0.901241
# Y06  0.840827  0.795471  0.752037  0.838379  0.852777
# Y07  0.746129  0.698961  0.652907  0.743822  0.763417
# Y08  0.902829  0.897089  0.872612  0.896547  0.894345
# Y09  0.947931  0.923403  0.889321  0.947002  0.951074
# Y10  0.945833  0.931275  0.899919  0.947893  0.950790
# Y11  0.933180  0.911746  0.879923  0.932860  0.936655
# Y12  0.825280  0.778135  0.733078  0.817218  0.830264
# Y13  0.951228  0.958731  0.938310  0.950045  0.950898
# Y14  0.911123  0.931548  0.916300  0.915336  0.906674
# Y15  0.925800  0.906402  0.874344  0.919587  0.929539
# ...

# %%
train_T_sensor_corr[Temperature].loc['Y00':].mean(axis=1)
# Out:
# Y00    0.941415
# Y01    0.957616
# Y02    0.960770
# Y03    0.786854
# Y04    0.786081
# Y05    0.892713
# Y06    0.815898
# Y07    0.721047
# Y08    0.892685
# Y09    0.931746
# Y10    0.935142
# Y11    0.918873
# Y12    0.796795
# Y13    0.949842
# Y14    0.916196
# Y15    0.911134
# Y16    0.902422
# Y17    0.892831
# dtype: float64

# %%
avg_corr = train_T_sensor_corr[Temperature].loc['Y00':].mean(axis=1)
over0_95 = avg_corr > 0.95
avg_corr[over0_95]
# Out:
# Y01    0.957616
# Y02    0.960770
# dtype: float64

# %%
over0_9 = avg_corr > 0.9
avg_corr[over0_9]
# Out:
# Y00    0.941415
# Y01    0.957616
# Y02    0.960770
# Y09    0.931746
# Y10    0.935142
# Y11    0.918873
# Y13    0.949842
# Y14    0.916196
# Y15    0.911134
# Y16    0.902422
# dtype: float64

# %%
(0.912809+0.979172+0.974490+0.918779+0.921823)/5
# Out:
# 0.9414145999999999
