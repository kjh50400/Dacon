# %%
import pandas as pd
from IPython.display import display
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
from matplotlib import gridspec
# %matplotlib inline

from matplotlib import font_manager, rc
font_path='c:/Windows/Fonts/malgun.ttf'
font_name= font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
highest = pd.read_csv('./output/30F_7대3.csv', index_col='id')
mine = pd.read_csv('./output/200331_drop windD_N_momentValue solarNrain_GRU_result.csv', index_col='id')

display(highest.head())
display(mine.head())
# Out:
#             Y18
# id
# 4752  19.770844
# 4753  19.779922
# 4754  19.732399
# 4755  19.516209
# 4756  19.474506
#             Y18
# id
# 4752  21.175344
# 4753  21.098457
# 4754  21.083100
# 4755  21.077414
# 4756  20.998300

# %%
highest.rename(columns={'Y18':'highest_Y18'}, inplace=True)
mine.rename(columns={'Y18':'mine_Y18'}, inplace=True)

display(highest.head())
display(mine.head())
# Out:
#       highest_Y18
# id
# 4752    19.770844
# 4753    19.779922
# 4754    19.732399
# 4755    19.516209
# 4756    19.474506
#        mine_Y18
# id
# 4752  21.175344
# 4753  21.098457
# 4754  21.083100
# 4755  21.077414
# 4756  20.998300

# %%
df = pd.concat([highest, mine], axis=1)
display(df)
# Out:
#        highest_Y18   mine_Y18
# id
# 4752     19.770844  21.175344
# 4753     19.779922  21.098457
# 4754     19.732399  21.083100
# 4755     19.516209  21.077414
# 4756     19.474506  20.998300
# ...            ...        ...
# 16267    27.357298  24.279722
# 16268    27.580605  24.593077
# 16269    27.645756  24.999998
# 16270    26.073930  25.012691
# 16271    26.783382  24.602686
#
# [11520 rows x 2 columns]

# %%
df['diff'] = df['highest_Y18'] - df['mine_Y18']
df.head()
# Out:
#       highest_Y18   mine_Y18      diff
# id
# 4752    19.770844  21.175344 -1.404500
# 4753    19.779922  21.098457 -1.318535
# 4754    19.732399  21.083100 -1.350701
# 4755    19.516209  21.077414 -1.561205
# 4756    19.474506  20.998300 -1.523794

# %%
# df['highest_Y18'].plot(figsize=(20,10))
# df['mine_Y18'].plot(figsize=(20,10))
# df['diff'].plot(figsize=(40,20))
df.plot(figsize=(40,20))
plt.legend()
plt.show()

# %%
abs(df['diff']).mean()
# Out:
# 1.8877473986111113
